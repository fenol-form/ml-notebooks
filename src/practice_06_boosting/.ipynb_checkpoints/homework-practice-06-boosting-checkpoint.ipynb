# %% [markdown]
# # Машинное обучение, ФКН ВШЭ
#
# # Практическое задание 6. Бустинговое
#
# ## Общая информация
#
# Дата выдачи: 12.12.2023
#
# Мягкий дедлайн: 24.12.2023 23:59 MSK
#
# Жёсткий дедлайн: 24.12.2023 23:59 MSK
#
# ## Оценивание и штрафы
#
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
#
# ## Формат сдачи
# Задания сдаются через систему anytask. Посылка должна содержать:
# * Ноутбук homework-practice-06-Username.ipynb
#
# Username — ваша фамилия на латинице

# %% [markdown]
# ## О задании
#
# В этом задании вам предстоит вручную запрограммировать один из самых мощных алгоритмов машинного обучения — бустинг.

# %%
from warnings import filterwarnings

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.sparse import load_npz
from sklearn.model_selection import train_test_split


# %config InlineBackend.figure_format = 'retina'
plt.rcParams['font.size'] = 12
sns.set(style='darkgrid')
filterwarnings('ignore')

# %%
x = load_npz('x.npz')
y = np.load('y.npy')

# %% [markdown]
# Разделим на обучающую, валидационную и тестовую выборки (`random_state` оставьте равным 1337 для воспроизводимости).

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1337)

x_test, x_valid, y_test, y_valid = train_test_split(x_test, y_test, test_size=0.5, random_state=1337)

x_train.shape, x_valid.shape, x_test.shape
# Out:
# ((18825, 169), (2354, 169), (2353, 169))

# %% [markdown]
# ## Задание 1. Реализация градиентного бустингового (4 балла)
#
# Вам нужно дописать код в файлике `boosting.py`. Для вас уже подготовлен шаблон класса `Boosting`, вы можете менять его по своему усмотрению.
#
# ### Инструкции для функций:
#
# #### `__init__`
#
# В `__init__` приходит кучка параметров, распишем что есть что:
#
#  - `base_model_class` - класс базовой модели нашего бустинга
#  - `base_model_params` - словарь с гиперпараметрами для базовой модели
#  - `n_estimators` - какое количество базовых моделей нужно обучить
#  - `learning_rate` - темп обучения, должен быть из полуинтервала $(0, 1]$
#  - `subsample` - доля объектов, на которой будет обучаться базовая модель (какую часть составляет бутстрапная выборка от исходной обучающей)
#  - `early_stopping_rounds` - число итераций, после которых при отсутствии улучшения качества на валидационной выборке обучение останавливается
#  - `plot` - строить ли после обучения всех базовых моделей график с качеством
#
# #### `fit`
#
# В `fit` приходит две выборки, обучающая и валидационная. На обучающей мы обучаем новые базовые модели, на валидационной считаем качество для ранней остановки (если это предусматривают параметры).
#
# Сначала нам нужно сделать какую-то нулевую модель, сделать предсказания для обучающей и валидационной выборок (в шаблоне это нулевая модель, соответственно предсказания это просто `np.zeros`). После этого нужно обучить `n_estimators` базовых моделей (как и на что обучаются базовые модели смотрите в лекциях и семинарах). После каждой обученной базовой модели мы должны обновить текущие предсказания, посчитать ошибку на обучающей и валидационной выборках (используем `loss_fn` для этого), проверить на раннюю остановку.
#
# После всего цикла обучения надо нарисовать график (если `plot`).
#
#
# #### `fit_new_base_model`
#
# В `fit_new_base_model` приходит обучающая выборка (целиком) и текущие предсказания для неё. Мы должны сгенерировать бутстрап выборку для обучения базовой модели и обучить базовую модель. После обучения модели запускаем поиск оптимальной гаммы, добавляем новую модель и гамму (не забываем про темп обучения) в соответствующие списки.
#
# #### `predict_proba`
#
# В `predict_proba` приходит выборка, нужно предсказать вероятности для неё. Суммируем предсказания базовых моделей на этой выборке (не забываем про гаммы) и накидываем сигмоиду.

# %%
% load_ext autoreload
# Out:
# UsageError: Line magic function `%` not found.

# %%
# % autoreload 2

from boosting import Boosting

# %% [markdown]
# ### Проверка кода
#
# У автора задания всё учится около одной секунды.

# %%
boosting = Boosting()

boosting.fit(x_train, y_train, x_valid, y_valid)

assert len(boosting.models) == boosting.n_estimators
assert len(boosting.gammas) == boosting.n_estimators

assert boosting.predict_proba(x_test).shape == (x_test.shape[0], 2)

print(f'Train ROC-AUC {boosting.score(x_train, y_train):.4f}')
print(f'Valid ROC-AUC {boosting.score(x_valid, y_valid):.4f}')
print(f'Test ROC-AUC {boosting.score(x_test, y_test):.4f}')
# Out:
# Train ROC-AUC 0.9921
# Valid ROC-AUC 0.9004
# Test ROC-AUC 0.9001

# %% [markdown]
# ## Задание 2. Обучение градиентного бустингового (1 балл)
#
# Оцените качество на тестовой выборке вашей имплементации бустинга для различной максимальной глубины решающего дерева в качестве базовой модели. Здесь и далее мы будем использовать метрику ROC-AUC.
#
# Перебирайте максимальную глубину от 1 до 30 с шагом 2 (остальные параметры бустинга стоит оставить равными по умолчанию). Постройте график зависимости качества на обучающей и тестовой выборке в зависимости от глубины.

# %%
results = {}

depths = range(1, 30, 2)

# YOUR CODE:

train_scores = []
test_scores = []
for depth in depths:
    base_model_params = {"max_depth": depth}
    boosting = Boosting(base_model_params=base_model_params)
    boosting.fit(x_train, y_train, x_valid, y_valid)
    train_scores.append(boosting.score(x_train, y_train))
    test_scores.append(boosting.score(x_test, y_test))

plt.plot(depths, train_scores, label="train scores")
plt.plot(depths, test_scores, label="test scores")
plt.legend()
plt.xlabel("depth")
plt.ylabel("score")
plt.title("model scores on depths")
# Out:
# Text(0.5, 1.0, 'model scores on depths')

# %% [markdown]
# **Какая из моделей имеет лучшее качество? Как вы можете это объяснить?**
#
# `### ваше решение тут ###`

# %% [markdown]
# Лучшее качество имеет модель с глубиной дерева ~ 7. После этого значения глубины ошибка на тестовых данных начинает убывать. Это происходит из-за того, что базовые модели становятся слишком сложными и бустинг начинает переобучаться

# %% [markdown]
# ## Задание 3. Подбираем гиперпараметры и ищем лучшую модель (3 балла)
#
# Подберите по валидационной выборке основные гиперпараметры для вашей модели бустинга. Следует подобрать все основные параметры для самого градиентного бустинга и для самих базовых моделей. Существуют библиотеки для подбора гиперпараметров, попробуйте использовать какую-нибудь из следующих двух - [Hyperopt](https://github.com/hyperopt/hyperopt), [Optuna](https://optuna.org/).

# %%
# YOUR CODE:
from hyperopt import hp, tpe, fmin, space_eval, Trials

def objective(params):
    n_estimators = params["n_estimators"]
    learning_rate = params["learning_rate"]
    early_stopping_rounds = params["early_stopping_rounds"]
    subsample = params["subsample"]
    params = params["base_model_params"]
    
    boosting = Boosting(
        n_estimators=n_estimators,
        learning_rate=learning_rate,
        early_stopping_rounds=early_stopping_rounds,
        subsample=subsample,
        base_model_params=params
    )
    boosting.fit(x_train, y_train, x_valid, y_valid)

    return boosting.score(x_valid, y_valid)

space = {
    "n_estimators": hp.randint("n_estimators", 7, 20),
    "learning_rate": hp.uniform("lr", 0.07, 0.16),
    "subsample": hp.uniform("subsample", 0.2, 0.3),
    "early_stopping_rounds": hp.choice(
        "early_stopping_rounds",
        [
            5, 10, 15, None
        ]
    ),
    "base_model_params": {
        "max_depth": hp.randint("max_depth", 2, 6),
        "min_samples_leaf": hp.randint("min_samples_leaf", 1, 5),
        "min_samples_split": hp.randint("min_samples_split", 2, 6),
    },
}

best = fmin(
    objective,
    space,
    algo=tpe.suggest,
    max_evals=1000,
)
# Out:
# {'base_model_params': {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}, 'early_stopping_rounds': 10, 'learning_rate': 0.14213635277604786, 'n_estimators': 14, 'subsample': 0.29343185210396566}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.10746502416340296, 'n_estimators': 10, 'subsample': 0.240500567455196}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.12497703730669701, 'n_estimators': 9, 'subsample': 0.22934979075148776}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}, 'early_stopping_rounds': 10, 'learning_rate': 0.14236629266423806, 'n_estimators': 11, 'subsample': 0.23661977774937976}
# {'base_model_params': {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 4}, 'early_stopping_rounds': None, 'learning_rate': 0.14650468080018936, 'n_estimators': 14, 'subsample': 0.24630249347090793}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 5}, 'early_stopping_rounds': 15, 'learning_rate': 0.09218307449399914, 'n_estimators': 11, 'subsample': 0.25284670154043304}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 4}, 'early_stopping_rounds': 5, 'learning_rate': 0.09086759457771926, 'n_estimators': 13, 'subsample': 0.2842869612764851}
# {'base_model_params': {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 5}, 'early_stopping_rounds': None, 'learning_rate': 0.15515495774790908, 'n_estimators': 16, 'subsample': 0.26488972426294366}
# {'base_model_params': {'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 2}, 'early_stopping_rounds': 10, 'learning_rate': 0.11805209457160867, 'n_estimators': 18, 'subsample': 0.2896896202883101}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 3}, 'early_stopping_rounds': 10, 'learning_rate': 0.13044187088866765, 'n_estimators': 11, 'subsample': 0.2224482381458917}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 5}, 'early_stopping_rounds': 10, 'learning_rate': 0.09565745160916309, 'n_estimators': 19, 'subsample': 0.29829515367750603}
# {'base_model_params': {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 4}, 'early_stopping_rounds': 15, 'learning_rate': 0.09624356985528608, 'n_estimators': 7, 'subsample': 0.2903489898009475}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 4}, 'early_stopping_rounds': None, 'learning_rate': 0.11152416257468985, 'n_estimators': 8, 'subsample': 0.21775413835126717}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}, 'early_stopping_rounds': 10, 'learning_rate': 0.09982437545701274, 'n_estimators': 12, 'subsample': 0.2191633064575843}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 3}, 'early_stopping_rounds': 5, 'learning_rate': 0.13772450599941605, 'n_estimators': 15, 'subsample': 0.2993642401287431}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 3}, 'early_stopping_rounds': 15, 'learning_rate': 0.11804987217518592, 'n_estimators': 14, 'subsample': 0.2775933160300537}
# {'base_model_params': {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 4}, 'early_stopping_rounds': 15, 'learning_rate': 0.1289816187221533, 'n_estimators': 8, 'subsample': 0.2413754816992991}
# {'base_model_params': {'max_depth': 3, 'min_samples_leaf': 3, 'min_samples_split': 3}, 'early_stopping_rounds': 10, 'learning_rate': 0.14907394227905685, 'n_estimators': 19, 'subsample': 0.2972706748192916}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 4}, 'early_stopping_rounds': None, 'learning_rate': 0.09874626346188142, 'n_estimators': 7, 'subsample': 0.2263649138131744}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}, 'early_stopping_rounds': 15, 'learning_rate': 0.09690125107768584, 'n_estimators': 17, 'subsample': 0.2940929690243291}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': None, 'learning_rate': 0.07589026606558931, 'n_estimators': 9, 'subsample': 0.20079573011659088}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 4}, 'early_stopping_rounds': 5, 'learning_rate': 0.11129095586304383, 'n_estimators': 8, 'subsample': 0.201809625548021}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 4}, 'early_stopping_rounds': 5, 'learning_rate': 0.07963167802918862, 'n_estimators': 9, 'subsample': 0.20125551261435504}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.13053781785607393, 'n_estimators': 8, 'subsample': 0.21196600464761495}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.12766710839453993, 'n_estimators': 9, 'subsample': 0.21288306779022234}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.15659485678243157, 'n_estimators': 15, 'subsample': 0.21005485737527532}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.12420303803023597, 'n_estimators': 9, 'subsample': 0.2288296768875172}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.13447467417776587, 'n_estimators': 18, 'subsample': 0.25738810795702083}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.12059151008022195, 'n_estimators': 10, 'subsample': 0.23319366271858294}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.1368224171331345, 'n_estimators': 13, 'subsample': 0.2083995235671941}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.15016354571305235, 'n_estimators': 12, 'subsample': 0.26101670070550737}
# {'base_model_params': {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.10572067134986472, 'n_estimators': 16, 'subsample': 0.2703987618698281}
# {'base_model_params': {'max_depth': 3, 'min_samples_leaf': 2, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.14442851795729225, 'n_estimators': 8, 'subsample': 0.2448222914256947}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 5}, 'early_stopping_rounds': 5, 'learning_rate': 0.10527871408178417, 'n_estimators': 17, 'subsample': 0.23644409321351098}
# {'base_model_params': {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}, 'early_stopping_rounds': 5, 'learning_rate': 0.1406447766112109, 'n_estimators': 9, 'subsample': 0.23016303023812856}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 4, 'min_samples_split': 5}, 'early_stopping_rounds': 5, 'learning_rate': 0

# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2}, 'early_stopping_rounds': 10, 'learning_rate': 0.09533373395822693, 'n_estimators': 14, 'subsample': 0.20694937427059504}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 3, 'min_samples_split': 3}, 'early_stopping_rounds': 10, 'learning_rate': 0.08582375857090103, 'n_estimators': 9, 'subsample': 0.24542470863088636}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 2, 'min_samples_split': 3}, 'early_stopping_rounds': 5, 'learning_rate': 0.13807098143582594, 'n_estimators': 10, 'subsample': 0.2370627415315315}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 4}, 'early_stopping_rounds': 10, 'learning_rate': 0.14624514394426982, 'n_estimators': 19, 'subsample': 0.2503384708609187}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 2}, 'early_stopping_rounds': None, 'learning_rate': 0.11833902438951051, 'n_estimators': 7, 'subsample': 0.23017501355211936}
# {'base_model_params': {'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 3}, 'early_stopping_rounds': 10, 'learning_rate': 0.10637155296659158, 'n_estimators': 8, 'subsample': 0.2332463392959631}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 3}, 'early_stopping_rounds': 15, 'learning_rate': 0.10114895639037365, 'n_estimators': 7, 'subsample': 0.24265270591056898}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 3}, 'early_stopping_rounds': 10, 'learning_rate': 0.09036603840848051, 'n_estimators': 18, 'subsample': 0.226174027386178}
# {'base_model_params': {'max_depth': 3, 'min_samples_leaf': 2, 'min_samples_split': 5}, 'early_stopping_rounds': 10, 'learning_rate': 0.09776479943267233, 'n_estimators': 7, 'subsample': 0.25510570784297604}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 2}, 'early_stopping_rounds': 10, 'learning_rate': 0.09401192655281675, 'n_estimators': 13, 'subsample': 0.2377481563988811}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 3}, 'early_stopping_rounds': 10, 'learning_rate': 0.11064686951304238, 'n_estimators': 7, 'subsample': 0.2509629991703426}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 3}, 'early_stopping_rounds': 10, 'learning_rate': 0.07869004122202092, 'n_estimators': 16, 'subsample': 0.21820548486230432}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 2}, 'early_stopping_rounds': 10, 'learning_rate': 0.10006304480502842, 'n_estimators': 12, 'subsample': 0.24488262746408304}
# {'base_model_params': {'max_depth': 4, 'min_samples_leaf': 2, 'min_samples_split': 3}, 'early_stopping_rounds': 10, 'learning_rate': 0.09237499504000163, 'n_estimators': 7, 'subsample': 0.25326475591745085}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 3}, 'early_stopping_rounds': 5, 'learning_rate': 0.10877496691513293, 'n_estimators': 15, 'subsample': 0.23181068398212584}
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 4}, 'early_stopping_rounds': 10, 'learning_rate': 0.07584710407685932, 'n_estimators': 8, 'subsample': 0.2576123372058442}
# 100%|█████████████████████| 1000/1000 [03:14<00:00,  5.14trial/s, best loss: 0.9025213256675072]

# %%
from hyperopt import space_eval
best = space_eval(space, best)

# %% [markdown]
# ## Задание 4. Интерпретация бустингового (2 балл)
#
# Постройте калибровочную кривую для вашей лучшей модели бустинга. Насколько хорошо бустинг оценивает вероятности? Постройте также калибровочную кривую для логистической регрессии, сравните их между собой. Проанализируйте полученные результаты.

# %%
# YOUR CODE:
def plot_calibration_curve(y_test, y_pred, nbins=10, ax=None, ax_title=""):
    bin_points = []
    bin_real_ratios = []
    for i in range(nbins):
        l = 1.0 / nbins * i
        r = 1.0 / nbins * (i + 1)
        bin_points.append((l + r) / 2)
        bin_real_ratios.append(np.mean(y_test[(y_pred >= l) & (y_pred < r)] == 1))
    plt.grid()
    ax.plot(bin_points, bin_real_ratios)
    ax.plot([0, 1], [0, 1], linestyle="--")
    ax.set_ylim([-0.05, 1.05])
    ax.set_title(ax_title)
    

boosting = Boosting(
    n_estimators=best["n_estimators"],
    learning_rate=best["learning_rate"],
    early_stopping_rounds=best["early_stopping_rounds"],
    subsample=best["subsample"],
    base_model_params=best["base_model_params"]
)

boosting.fit(x_train, y_train, x_valid, y_valid)
boosting_pred = boosting.predict_proba(x_valid)[:, 1]

from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(x_train, y_train)
lr_pred = lr.predict_proba(x_valid)[:, 1]

_, axes = plt.subplots(1, 2, figsize=(12, 5))

plot_calibration_curve(y_valid, boosting_pred, ax=axes[0], ax_title="boosting calibration curve")
plot_calibration_curve(y_valid, lr_pred, ax=axes[1], ax_title="LR calibration curve")
boosting_pred
# Out:
# array([0.48239869, 0.54287109, 0.46679765, ..., 0.53792355, 0.54287109,
#        0.54287109])

# %% [markdown]
# Теперь попробуем оценить важность признаков для бустинга.
#
# Поскольку наша базовая модель - это дерево из `sklearn`, мы можем вычислить важность признака отдельно для каждого дерева и усреднить (воспользуйтесь `feature_importances_` у `DecisionTreeRegressor`), после этого нормировать значения, чтобы они суммировались в единицу (обратите внимание, что они должны быть неотрицательными - иначе вы что-то сделали не так).
#
# Допишите в вашей реализации бустинга функцию `feature_importances_` чтобы она возвращала описанные выше важности признаков.
#
# Нарисуйте столбчатую диаграмму важности признаков. На соседнем графике нарисуйте важность признаков для логистической регрессии, для этого используйте модули весов. Сравните графики. Проанализируйте полученные результаты.

# %%
# YOUR CODE:

# %% [markdown]
# Кстати, чаще всего излишние признаки могут вредить качеству бустинга. Попробуйте отфильтровать на основании диаграммы хвост наименее важных признаков и снова обучить модель (с теми же гиперпараметрами). Стало ли лучше?

# %%
# YOUR CODE:

# %% [markdown]
# ## Задание 5 (бонус). Блендинговое (1 балл)
#
# Реализуйте блендинг над вашей лучшей моделью и логистической регрессией. Улучшилось ли качество?

# %%
# YOUR CODE:

# %% [markdown]
# ## Задание 6 (бонус). Катбустовое (1 балл)
#
# Запустите [CatBoost](https://catboost.ai/en/docs/concepts/python-quickstart) на наших данных, сравните с вашей реализацией. Где получилось лучше?

# %%
# YOUR CODE:
from catboost import CatBoostClassifier

clf = CatBoostClassifier(
    iterations=best["n_estimators"],
    learning_rate=best["learning_rate"],
    depth=best["base_model_params"]["max_depth"],
    subsample=best["subsample"],
    early_stopping_rounds=best["early_stopping_rounds"],
    min_data_in_leaf=best["base_model_params"]["min_samples_leaf"],
)
clf.fit(x_train, y_train)
pred = clf.predict_proba(x_valid)

from sklearn.metrics import roc_auc_score

print("CatBoostClassifier ROC-AUC score =", roc_auc_score(y_valid == 1, pred[:, 1]))
print("My boosting ROC-AUC score =", objective(best))
# Out:
# 0:	learn: 0.6189268	total: 3.77ms	remaining: 22.6ms
# 1:	learn: 0.5618717	total: 7.01ms	remaining: 17.5ms
# 2:	learn: 0.5200815	total: 9.17ms	remaining: 12.2ms
# 3:	learn: 0.4863604	total: 10.9ms	remaining: 8.15ms
# 4:	learn: 0.4640694	total: 13.8ms	remaining: 5.52ms
# 5:	learn: 0.4380259	total: 15.8ms	remaining: 2.64ms
# 6:	learn: 0.4230490	total: 17.9ms	remaining: 0us
# CatBoostClassifier ROC-AUC score = 0.9059746989423172
# {'base_model_params': {'max_depth': 2, 'min_samples_leaf': 3, 'min_samples_split': 3}, 'early_stopping_rounds': 10, 'learning_rate': 0.0954196054144762, 'n_estimators': 7, 'subsample': 0.23108486302051678}
# My boosting ROC-AUC score = 0.9118721329977739

# %% [markdown]
# Написанный бустинг отработал лучше, видимо, потому, что гиперпараметры были специально подобраны под него

# %% [markdown]
# ## Социализационный бонус. Новогоднее 🎆 (0.5 балла)
#
# Сфотографируйтесь с наряженной новогодней или рождественской ёлкой! Приложите фотографию, опишите свои впечатления, чего вы ждете от нового 2024 года?
